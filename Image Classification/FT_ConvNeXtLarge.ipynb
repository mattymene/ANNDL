# %% [markdown]
# # Artificial Neural Networks and Deep Learning Challenge 1: Image Classification of a RGB 96x96 blood cells dataset
# In this assignment, we built a model to classify 96x96 RGB images of blood cells. These images are categorized into eight classes, each representing a particular cell state. This is a multi-class classification problem, so the goal is to assign the correct class label to each RGB image.
#
# cleaned_no_duplicates.npz is the train dataset, already cleared from outliers and duplicates.
#
# ---
# ## How to run with this notebook
# Follow these steps:
# - If in Colab:
# 0. This notebook is expected to be opened and executed from a Google Drive folder called `ANNDL-challenge1`, which should also contain the `cleaned_no_duplicates.npz` file
# 1. Create a folder named `ANNDL-challenge1` in your Google Drive.
# 2. Upload the `cleaned_no_duplicates.npz` file to this folder.
# 3. Upload and run this notebook.
#
# - If in Kaggle:
# 0. This notebook is expected to be executed from Kaggle
# 1. Upload the `cleaned_no_duplicates.npz` file to Kaggle.
# 2. Run this notebook.

# %% [markdown]
# ## Settings Variables

# %%
# To run the code alternatively in Colab or Kaggle
IS_COLAB = True

# Seed for Randomness
SEED = 42

# Name of the file for plotting validation/test accuracy and loss of all the models trained in the past
METADATA_FILE = 'metadata.pkl'

# Set Dataset path
if IS_COLAB :
    DATA_FILE = 'cleaned_no_duplicates.npz'
else:
    # (Kaggle) Dataset file path
    DATA_FILE = '/kaggle/input/cleaned-no-duplicates-cells/cleaned_no_duplicates.npz'

# %% [markdown]
# ## Model Parameters

# %%
# Ratio of validation set wrt the whole dataset
VALIDATION_SPLIT = 0.1

# Batch size for training
BATCH_SIZE = 64

# %% [markdown]
# ## 🌐 Connect Colab to Google Drive

# %%
if IS_COLAB:
    from google.colab import drive

    drive.mount('/gdrive')
    # %cd /gdrive/My Drive/ANNDL-challenge1
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/ANNDL-challenge1

# %% [markdown]
# ## ⚙️ Import Libraries

# %%
# !pip install keras-cv
# Out:
# Collecting keras-cv
#   Downloading keras_cv-0.9.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-cv) (24.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras-cv) (1.4.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from keras-cv) (2024.9.11)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.10/dist-packages (from keras-cv) (4.9.7)
# Collecting keras-core (from keras-cv)
#   Downloading keras_core-0.1.7-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.10/dist-packages (from keras-cv) (0.3.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kagglehub->keras-cv) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kagglehub->keras-cv) (4.66.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv) (3.12.1)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv) (0.1.8)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (8.1.7)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (4.2.1)
# Requirement already satisfied: promise in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (2.3)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (4.25.5)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (5.9.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (17.0.0)
# Requirement already satisfied: simple-parsing in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (0.1.6)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (1.13.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (2.5.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (0.10.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (1.16.0)
# Requirement already satisfied: array-record>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (0.5.1)
# Requirement already satisfied: etils>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (1.10.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (2024.10.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (6.4.5)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (4.12.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras-cv) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras-cv) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras-cv) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras-cv) (2024.8.30)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from promise->tensorflow-datasets->keras-cv) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-core->keras-cv) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-core->keras-cv) (2.18.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /usr/local/lib/python3.10/dist-packages (from simple-parsing->tensorflow-datasets->keras-cv) (0.16)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-metadata->tensorflow-datasets->keras-cv) (1.66.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras-core->keras-cv) (0.1.2)
# Downloading keras_cv-0.9.0-py3-none-any.whl (650 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 650.7/650.7 kB 31.9 MB/s eta 0:00:00
# Downloading keras_core-0.1.7-py3-none-any.whl (950 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.8/950.8 kB 54.1 MB/s eta 0:00:00
# Installing collected packages: keras-core, keras-cv
# Successfully installed keras-core-0.1.7 keras-cv-0.9.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
from tensorflow.keras.applications.mobilenet import preprocess_input
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score
import keras_cv

import os
import shutil
import pickle
from collections import Counter

np.random.seed(SEED)
tf.random.set_seed(SEED)
tf.compat.v1.set_random_seed(SEED)

plt.rc('font', size=14)

# %% [markdown]
# ## Load Metadata to Store Histories

# %%
if os.path.exists(METADATA_FILE):
    with open(METADATA_FILE, 'rb') as f:
        metadata = pickle.load(f)
else:
    metadata = {}

# %% [markdown]
# ## ⏳ Load the Data

# %%
with np.load(DATA_FILE) as data:
    X = data['images']
    y = data['labels']

print("Shape of X:", X.shape)
print("Shape of y:", y.shape)

# Define a mapping of labels to their corresponding names
labels = {0:'Basophil', 1:'Eosinophil', 2:'Erythroblast', 3:'Granulocytes',
          4:'Lymphocyte', 5:'Monocyte', 6:'Neutrophil', 7:'Platelet'}

unique_labels = np.unique(y)
# Out:
# Shape of X: (11951, 96, 96, 3)
# Shape of y: (11951, 1)

# %% [markdown]
# ## Visualize Distribution of Class Labels in the Dataset
# Show the distribution of Class Labels in the Dataset and first image for each class

# %%
# Distribuzione delle etichette
labels_count = Counter(y.flatten())
plt.bar(labels_count.keys(), labels_count.values())
plt.xlabel("Class Label")
plt.ylabel("Frequency")
plt.title("Distribution of Class Labels in the Dataset")
plt.show()

fig, axes = plt.subplots(1, len(unique_labels), figsize=(20, 15))

for i, label in enumerate(unique_labels):
    idx = np.where(y == label)[0][0]  # Trova l'indice della prima immagine con questa etichetta
    axes[i].imshow(X[idx])
    axes[i].set_title(labels[label] + ' [' + str(label) + ']')
    axes[i].axis('off')

plt.show()

# %% [markdown]
# ## Apply Class Weights
# for compensating the dataset imbalancement during training

# %%
# Calculate Class Weights Based on the class distributions
class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y), y=y.ravel())
class_weights_dict = dict(enumerate(class_weights))
print("Class weights:", class_weights_dict)
# Out:
# Class weights: {0: 1.7575, 1: 0.6855782469022488, 2: 1.3768433179723503, 3: 0.7384453781512605, 4: 1.7595700824499412, 5: 1.505922379032258, 6: 0.6411480686695279, 7: 0.9092361533779671}

# %% [markdown]
# ## Data Preprocessing
# Split the dataset

# %%
# X = (X / 255).astype('float32')

# Convert labels to categorical format using one-hot encoding
y = tfk.utils.to_categorical(y)

X_train, X_val, y_train, y_val = train_test_split(X, y, stratify=y, test_size=VALIDATION_SPLIT, random_state=SEED)

# Print the shapes of the resulting datasets
print("Training Data Shape:", X_train.shape)
print("Training Label Shape:", y_train.shape)
print("Validation Data Shape:", X_val.shape)
print("Validation Label Shape:", y_val.shape)
# Out:
# Training Data Shape: (10755, 96, 96, 3)
# Training Label Shape: (10755, 8)
# Validation Data Shape: (1196, 96, 96, 3)
# Validation Label Shape: (1196, 8)

# %% [markdown]
# Apply Augmentation (RandAugment and Augmix) and print some agumented images

# %%
rand_augment = keras_cv.layers.RandAugment(
    value_range=(0, 255),
    augmentations_per_image=3,
    magnitude=0.5
)

augmix = keras_cv.layers.AugMix(
    value_range=(0, 255),
    severity=0.3,
    num_chains=3,
    chain_depth=[1, 3],
)

train_dataset_augmented = (
    tf.data.Dataset.from_tensor_slices((X_train, y_train))
    .shuffle(BATCH_SIZE * 100)
    .batch(BATCH_SIZE)
    .map(
        lambda x, y: (rand_augment(augmix(tf.cast(x, tf.uint8))), y),
        num_parallel_calls=tf.data.AUTOTUNE,
    )
    .prefetch(tf.data.AUTOTUNE)
    .unbatch()
)

# %%
X_train_augmented = []
y_train_augmented = []

for element in train_dataset_augmented.as_numpy_iterator():
    X_train_augmented.append(element[0])
    y_train_augmented.append(element[1])

X_train_augmented = np.array(X_train_augmented)
y_train_augmented = np.array(y_train_augmented)

# %%
img_to_show = 10
fig, axes = plt.subplots(1, img_to_show, figsize=(4 * img_to_show, 4))

# Display some random images for each class
for i in range(img_to_show):
    ax = axes[i]
    ax.imshow(X_train_augmented[i] / 255)
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🛠️ Build the Model and Apply Transfer Learning
# We use a pre-trained CNN (model_supernet = ConvNeXtLarge) as FEN, and we add some FCLs at the end of it. Then, keeping the FEN (model_supernet = ConvNeXtLarge) frozen, we train the whole network.

# %%
# Input shape for the model
input_shape = X_train_augmented.shape[1:]

# Output shape for the model
output_shape = y_train_augmented.shape[1]

print("Input Shape:", input_shape)
print("Output Shape:", output_shape)
# Out:
# Input Shape: (96, 96, 3)
# Output Shape: 8

# %% [markdown]
# Apply an augmentation layer

# %%
augmentation_layer = tf.keras.Sequential([
    tfkl.RandomFlip("horizontal_and_vertical"),
    tfkl.RandomTranslation(0.2,0.2),
    tfkl.RandomRotation(0.35),
    tfkl.RandomZoom(0.2),
], name='augmentation')

# %% [markdown]
# Download the model to be used as a FEN

# %%
model_supernet = tfk.applications.ConvNeXtLarge(
    input_shape = input_shape,
    include_top = False,
    weights='imagenet',
)
model_supernet.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_large_notop.h5
# 785596384/785596384 ━━━━━━━━━━━━━━━━━━━━ 20s 0us/step

# %% [markdown]
# ## Transfer-Learning model parameters

# %%
# Number of training EPOCHS
EPOCHS = 1000

# Batch size for training
BATCH_SIZE = 64

# Learning rate: step size for updating the model's weights
LEARNING_RATE = 0.001

# Rate of the First Dropout layer
DROPOUT_RATE_FIRST=0.5

# Rate of the Other Dropout layers
DROPOUT_RATE_OTHERS=0.3

# L2 regularization
L2_LAMBDA = 0.001

# %%
def build_model(
    input_shape=input_shape,
    output_shape=output_shape,
    learning_rate=LEARNING_RATE,
    seed=SEED,
    l2_lambda=L2_LAMBDA
):
    initializer = tfk.initializers.HeUniform(seed)
    regulariser = tfk.regularizers.l2(l2_lambda)

    # Build the neural network layer by layer
    inputs = tfkl.Input(shape=input_shape, name='input')

    x = augmentation_layer(inputs)

    x = model_supernet(x)
    x = tfkl.Flatten(name='flatten')(x)
    x = tfkl.Dropout(DROPOUT_RATE_FIRST)(x)

    x = tfkl.Dense(units=1024, kernel_initializer=initializer, kernel_regularizer=regulariser, name='dense1')(x)
    x = tfkl.Dropout(DROPOUT_RATE_OTHERS)(x)
    x = tfkl.Activation('relu', name='actdense1')(x)

    x = tfkl.Dense(units=1024, kernel_initializer=initializer, kernel_regularizer=regulariser, name='dense2')(x)
    x = tfkl.Dropout(DROPOUT_RATE_OTHERS)(x)
    x = tfkl.Activation('relu', name='actdense2')(x)

    x = tfkl.Dense(units=output_shape, kernel_regularizer=regulariser, name='output')(x)
    outputs = tfkl.Activation('softmax', name='softmax')(x)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=inputs, outputs=outputs, name='CNN')

    # Compile the model
    loss = tfk.losses.CategoricalCrossentropy()
    optimizer = tfk.optimizers.Adam(learning_rate)
    metrics = ['accuracy']
    model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

    # Return the model
    return model

# %%
model = build_model()

# Display a summary of the model architecture
model.summary(expand_nested=True, show_trainable=True)

# Plot the model architecture
# tfk.utils.plot_model(model, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# Model: "CNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)                ┃ Output Shape          ┃    Param # ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━┩
# │ input (InputLayer)          │ (None, 96, 96, 3)     │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ augmentation (Sequential)   │ (None, 96, 96, 3)     │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ random_flip_1          │ (None, 96, 96, 3)     │          0 │   -   │
# │ (RandomFlip)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ random_translation_3   │ (None, 96, 96, 3)     │          0 │   -   │
# │ (RandomTranslation)         │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ random_rotation_1      │ (None, 96, 96, 3)     │          0 │   -   │
# │ (RandomRotation)            │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ random_zoom_1          │ (None, 96, 96, 3)     │          0 │   -   │
# │ (RandomZoom)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ convnext_large (Functional) │ (None, 3, 3, 1536)    │ 196,230,3… │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ input_layer            │ (None, 96, 96, 3)     │          0 │   -   │
# │ (InputLayer)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 96, 96, 3)     │          0 │   -   │
# │ convnext_large_prestem_nor… │                       │            │       │
# │ (Normalization)             │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ convnext_large_stem    │ (None, 24, 24, 192)   │      9,792 │   N   │
# │ (Sequential)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │       └                     │ (None, 24, 24, 192)   │      9,408 │   N   │
# │ convnext_large_stem_conv    │                       │            │       │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │       └                     │ (None, 24, 24, 192)   │        384 │   N   │
# │ convnext_large_stem_layern… │                       │            │       │
# │ (LayerNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 24, 24, 192)   │      9,600 │   N   │
# │ convnext_large_stage_0_blo… │                       │            │       │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 24, 24, 192)   │        384 │   N   │
# │ convnext_large_stage_0_blo… │                       │            │       │
# │ (LayerNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 24, 24, 768)   │    148,224 │   N   │
# │ convnext_large_stage_0_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 24, 24, 768)   │          0 │   -   │
# │ convnext_large_stage_0_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 24, 24, 192)   │    147,648 │   N   │
# │ convnext_large_stage_0_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 24, 24, 192)   │        192 │   N   │
# │ convnext_large_stage_0_blo… │                       │            │       │
# │ (LayerScale)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 24, 24, 192)   │          0 │   -   │
# │ convnext_large_stage_0_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 24, 24, 192)   │      9,600 │   N   │
# │ convnext_large_stage_0_blo… │                       │            │       │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 24, 24, 192)   │        384 │   N   │
# │ convnext_large_stage_0_blo… │                       │            │       │
# │ (LayerNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 24, 24, 768)   │    148,224 │   N   │
# │ convnext_large_stage_0_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 24, 24, 768)   │          0 │   -   │
# │ convnext_large_stage_0_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 24, 24, 192)   │    147,648 │   N   │
# │ convnext_large_stage_0_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 24, 24, 192)   │        192 │   N   │
# │ convnext_large_stage_0_blo… │                       │            │       │
# │ (LayerScale)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 24, 24, 192)   │          0 │   -   │
# │ convnext_large_stage_0_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 24, 24, 192)   │      9,600 │   N   │
# │ convnext_large_stage_0_blo… │                       │            │       │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 24, 24, 192)   │        384 │   N   │
# │ convnext_large_stage_0_blo… │                       │            │       │
# │ (LayerNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 24, 24, 768)   │    148,224 │   N   │
# │ convnext_large_stage_0_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 24, 24, 768)   │          0 │   -   │
# │ convnext_large_stage_0_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 24, 24, 192)   │    147,648 │   N   │
# │ convnext_large_stage_0_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 24, 24, 192)   │        192 │   N   │
# │ convnext_large_stage_0_blo… │                       │            │       │
# │ (LayerScale)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 24, 24, 192)   │          0 │   -   │
# │ convnext_large_stage_0_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 12, 12, 384)   │    295,680 │   N   │
# │ convnext_large_downsamplin… │                       │            │       │
# │ (Sequential)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │       └                     │ (None, 24, 24, 192)   │        384 │   N   │
# │ convnext_large_downsamplin… │                       │            │       │
# │ (LayerNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │       └                     │ (None, 12, 12, 384)   │    295,296 │   N   │
# │ convnext_large_downsamplin… │                       │            │       │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 12, 12, 384)   │     19,200 │   N   │
# │ convnext_large_stage_1_blo… │                       │            │       │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 12, 12, 384)   │        768 │   N   │
# │ convnext_large_stage_1_blo… │                       │            │       │
# │ (LayerNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 12, 12, 1536)  │    591,360 │   N   │
# │ convnext_large_stage_1_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 12, 12, 1536)  │          0 │   -   │
# │ convnext_large_stage_1_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 12, 12, 384)   │    590,208 │   N   │
# │ convnext_large_stage_1_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 12, 12, 384)   │        384 │   N   │
# │ convnext_large_stage_1_blo… │                       │            │       │
# │ (LayerScale)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 12, 12, 384)   │          0 │   -   │
# │ convnext_large_stage_1_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 12, 12, 384)   │     19,200 │   N   │
# │ convnext_large_stage_1_blo… │                       │            │       │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 12, 12, 384)   │        768 │   N   │
# │ convnext_large_stage_1_blo… │                       │            │       │
# │ (LayerNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 12, 12, 1536)  │    591,360 │   N   │
# │ convnext_large_stage_1_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 12, 12, 1536)  │          0 │   -   │
# │ convnext_large_stage_1_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 12, 12, 384)   │    590,208 │   N   │
# │ convnext_large_stage_1_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 12, 12, 384)   │        384 │   N   │
# │ convnext_large_stage_1_blo… │                       │            │       │
# │ (LayerScale)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 12, 12, 384)   │          0 │   -   │
# │ convnext_large_stage_1_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 12, 12, 384)   │     19,200 │   N   │
# │ convnext_large_stage_1_blo… │                       │            │       │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 12, 12, 384)   │        768 │   N   │
# │ convnext_large_stage_1_blo… │                       │            │       │
# │ (LayerNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 12, 12, 1536)  │    591,360 │   N   │
# │ convnext_large_stage_1_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 12, 12, 1536)  │          0 │   -   │
# │ convnext_large_stage_1_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 12, 12, 384)   │    590,208 │   N   │
# │ convnext_large_stage_1_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 12, 12, 384)   │        384 │   N   │
# │ convnext_large_stage_1_blo… │                       │            │       │
# │ (LayerScale)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 12, 12, 384)   │          0 │   -   │
# │ convnext_large_stage_1_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │  1,181,184 │   N   │
# │ convnext_large_downsamplin… │                       │            │       │
# │ (Sequential)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │       └                     │ (None, 12, 12, 384)   │        768 │   N   │
# │ convnext_large_downsamplin… │                       │            │       │
# │ (LayerNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │       └                     │ (None, 6, 6, 768)     │  1,180,416 │   N   │
# │ convnext_large_downsamplin… │                       │            │       │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │     38,400 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │      1,536 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (LayerNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 3072)    │  2,362,368 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 3072)    │          0 │   -   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │  2,360,064 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │        768 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (LayerScale)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │          0 │   -   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │     38,400 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │      1,536 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (LayerNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 3072)    │  2,362,368 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 3072)    │          0 │   -   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │  2,360,064 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │        768 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (LayerScale)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │          0 │   -   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │     38,400 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │      1,536 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (LayerNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 3072)    │  2,362,368 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 3072)    │          0 │   -   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │  2,360,064 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │        768 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (LayerScale)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │          0 │   -   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │     38,400 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │      1,536 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (LayerNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 3072)    │  2,362,368 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 3072)    │          0 │   -   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │  2,360,064 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │        768 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (LayerScale)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │          0 │   -   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │     38,400 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │      1,536 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (LayerNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 3072)    │  2,362,368 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 3072)    │          0 │   -   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │  2,360,064 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │        768 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (LayerScale)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │          0 │   -   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │     38,400 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │      1,536 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (LayerNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 3072)    │  2,362,368 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 3072)    │          0 │   -   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │  2,360,064 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │        768 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (LayerScale)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │          0 │   -   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │     38,400 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │      1,536 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (LayerNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 3072)    │  2,362,368 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 3072)    │          0 │   -   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │  2,360,064 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │        768 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (LayerScale)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │          0 │   -   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │     38,400 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │      1,536 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (LayerNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 3072)    │  2,362,368 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 3072)    │          0 │   -   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │  2,360,064 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │        768 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (LayerScale)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │          0 │   -   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │     38,400 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │      1,536 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (LayerNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 3072)    │  2,362,368 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 3072)    │          0 │   -   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │  2,360,064 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │        768 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (LayerScale)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │          0 │   -   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │     38,400 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │      1,536 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (LayerNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 3072)    │  2,362,368 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 3072)    │          0 │   -   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │  2,360,064 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │        768 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (LayerScale)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │          0 │   -   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │     38,400 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │      1,536 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (LayerNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 3072)    │  2,362,368 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 3072)    │          0 │   -   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │  2,360,064 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │        768 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (LayerScale)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │          0 │   -   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │     38,400 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │      1,536 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (LayerNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 3072)    │  2,362,368 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 3072)    │          0 │   -   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │  2,360,064 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │        768 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (LayerScale)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │          0 │   -   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │     38,400 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │      1,536 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (LayerNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 3072)    │  2,362,368 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 3072)    │          0 │   -   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │  2,360,064 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │        768 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (LayerScale)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │          0 │   -   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │     38,400 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │      1,536 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (LayerNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 3072)    │  2,362,368 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 3072)    │          0 │   -   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │  2,360,064 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │        768 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (LayerScale)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │          0 │   -   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# ...
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │     38,400 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │      1,536 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (LayerNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 3072)    │  2,362,368 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 3072)    │          0 │   -   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │  2,360,064 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │        768 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (LayerScale)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │          0 │   -   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │     38,400 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │      1,536 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (LayerNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 3072)    │  2,362,368 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 3072)    │          0 │   -   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │  2,360,064 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │        768 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (LayerScale)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │          0 │   -   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │     38,400 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │      1,536 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (LayerNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 3072)    │  2,362,368 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 3072)    │          0 │   -   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │  2,360,064 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │        768 │   N   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (LayerScale)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 6, 6, 768)     │          0 │   -   │
# │ convnext_large_stage_2_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 3, 3, 1536)    │  4,721,664 │   N   │
# │ convnext_large_downsamplin… │                       │            │       │
# │ (Sequential)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │       └                     │ (None, 6, 6, 768)     │      1,536 │   N   │
# │ convnext_large_downsamplin… │                       │            │       │
# │ (LayerNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │       └                     │ (None, 3, 3, 1536)    │  4,720,128 │   N   │
# │ convnext_large_downsamplin… │                       │            │       │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 3, 3, 1536)    │     76,800 │   N   │
# │ convnext_large_stage_3_blo… │                       │            │       │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 3, 3, 1536)    │      3,072 │   N   │
# │ convnext_large_stage_3_blo… │                       │            │       │
# │ (LayerNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 3, 3, 6144)    │  9,443,328 │   N   │
# │ convnext_large_stage_3_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 3, 3, 6144)    │          0 │   -   │
# │ convnext_large_stage_3_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 3, 3, 1536)    │  9,438,720 │   N   │
# │ convnext_large_stage_3_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 3, 3, 1536)    │      1,536 │   N   │
# │ convnext_large_stage_3_blo… │                       │            │       │
# │ (LayerScale)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 3, 3, 1536)    │          0 │   -   │
# │ convnext_large_stage_3_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 3, 3, 1536)    │     76,800 │   N   │
# │ convnext_large_stage_3_blo… │                       │            │       │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 3, 3, 1536)    │      3,072 │   N   │
# │ convnext_large_stage_3_blo… │                       │            │       │
# │ (LayerNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 3, 3, 6144)    │  9,443,328 │   N   │
# │ convnext_large_stage_3_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 3, 3, 6144)    │          0 │   -   │
# │ convnext_large_stage_3_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 3, 3, 1536)    │  9,438,720 │   N   │
# │ convnext_large_stage_3_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 3, 3, 1536)    │      1,536 │   N   │
# │ convnext_large_stage_3_blo… │                       │            │       │
# │ (LayerScale)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 3, 3, 1536)    │          0 │   -   │
# │ convnext_large_stage_3_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 3, 3, 1536)    │     76,800 │   N   │
# │ convnext_large_stage_3_blo… │                       │            │       │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 3, 3, 1536)    │      3,072 │   N   │
# │ convnext_large_stage_3_blo… │                       │            │       │
# │ (LayerNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 3, 3, 6144)    │  9,443,328 │   N   │
# │ convnext_large_stage_3_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 3, 3, 6144)    │          0 │   -   │
# │ convnext_large_stage_3_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 3, 3, 1536)    │  9,438,720 │   N   │
# │ convnext_large_stage_3_blo… │                       │            │       │
# │ (Dense)                     │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 3, 3, 1536)    │      1,536 │   N   │
# │ convnext_large_stage_3_blo… │                       │            │       │
# │ (LayerScale)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 3, 3, 1536)    │          0 │   -   │
# │ convnext_large_stage_3_blo… │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ layer_normalization    │ (None, 3, 3, 1536)    │      3,072 │   N   │
# │ (LayerNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ flatten (Flatten)           │ (None, 13824)         │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dropout (Dropout)           │ (None, 13824)         │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense1 (Dense)              │ (None, 1024)          │ 14,156,800 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dropout_1 (Dropout)         │ (None, 1024)          │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ actdense1 (Activation)      │ (None, 1024)          │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense2 (Dense)              │ (None, 1024)          │  1,049,600 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dropout_2 (Dropout)         │ (None, 1024)          │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ actdense2 (Activation)      │ (None, 1024)          │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ output (Dense)              │ (None, 8)             │      8,200 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ softmax (Activation)        │ (None, 8)             │          0 │   -   │
# └─────────────────────────────┴───────────────────────┴────────────┴───────┘
#  Total params: 211,444,936 (806.60 MB)
#  Trainable params: 15,214,600 (58.04 MB)
#  Non-trainable params: 196,230,336 (748.56 MB)

# %% [markdown]
# ## 🛠️ Train and Save the Model
# Use early stopping: ensuring the model stops training when validation accuracy stops improving for "patience" epochs, and the weights are restored to the best-performing epoch.

# %%
# Define the patience value for early stopping
patience = 20

# Create an EarlyStopping callback
early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=patience,
    restore_best_weights=True
)

# Store the callback in a list
callbacks = [early_stopping]

# %%
# Change this variable to change the name of the .keras file
MODEL_NAME = 'CONVLARGE'

# Train the model with early stopping callback
history = model.fit(
    x=X_train_augmented,
    y=y_train_augmented,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=(X_val, y_val),
    callbacks=callbacks,
    class_weight=class_weights_dict
).history

# Calculate and print the final validation accuracy
final_val_accuracy = round(max(history['val_accuracy'])* 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')

# Save the trained model to a file with the accuracy included in the filename
model_filename = 'CNN_'+MODEL_NAME+'_'+str(final_val_accuracy)+'.keras'
model.save(model_filename)

# Delete the model to free up resources
del model
# Out:
# Epoch 1/1000
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732128548.497313     118 service.cc:145] XLA service 0x7c3e27226da0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1732128548.497368     118 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1732128548.793125     118 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 175s 921ms/step - accuracy: 0.2939 - loss: 7.2944 - val_accuracy: 0.5903 - val_loss: 4.1270
# Epoch 2/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 148s 875ms/step - accuracy: 0.4730 - loss: 4.3465 - val_accuracy: 0.6472 - val_loss: 3.0332
# Epoch 3/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 148s 875ms/step - accuracy: 0.5221 - loss: 3.3068 - val_accuracy: 0.7860 - val_loss: 2.1927
# Epoch 4/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 147s 871ms/step - accuracy: 0.5490 - loss: 2.7226 - val_accuracy: 0.7625 - val_loss: 1.8479
# Epoch 5/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 148s 876ms/step - accuracy: 0.5822 - loss: 2.3348 - val_accuracy: 0.8520 - val_loss: 1.4991
# Epoch 6/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 148s 876ms/step - accuracy: 0.5926 - loss: 2.0830 - val_accuracy: 0.8980 - val_loss: 1.3178
# Epoch 7/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 147s 873ms/step - accuracy: 0.6163 - loss: 1.9216 - val_accuracy: 0.8905 - val_loss: 1.2068
# Epoch 8/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 147s 872ms/step - accuracy: 0.6197 - loss: 1.8312 - val_accuracy: 0.8721 - val_loss: 1.1860
# Epoch 9/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 147s 873ms/step - accuracy: 0.6190 - loss: 1.7716 - val_accuracy: 0.8846 - val_loss: 1.1373
# Epoch 10/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 147s 872ms/step - accuracy: 0.6401 - loss: 1.7021 - val_accuracy: 0.8838 - val_loss: 1.0265
# Epoch 11/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 147s 872ms/step - accuracy: 0.6430 - loss: 1.6830 - val_accuracy: 0.8972 - val_loss: 1.0549
# Epoch 12/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 147s 872ms/step - accuracy: 0.6226 - loss: 1.6665 - val_accuracy: 0.8838 - val_loss: 1.0490
# Epoch 13/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 147s 872ms/step - accuracy: 0.6478 - loss: 1.5988 - val_accuracy: 0.8821 - val_loss: 1.0053
# Epoch 14/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 147s 873ms/step - accuracy: 0.6273 - loss: 1.6258 - val_accuracy: 0.8018 - val_loss: 1.1067
# Epoch 15/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 147s 873ms/step - accuracy: 0.6426 - loss: 1.6030 - val_accuracy: 0.8863 - val_loss: 0.9631
# Epoch 16/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 148s 877ms/step - accuracy: 0.6493 - loss: 1.5395 - val_accuracy: 0.9339 - val_loss: 0.9395
# Epoch 17/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 147s 873ms/step - accuracy: 0.6429 - loss: 1.5774 - val_accuracy: 0.9164 - val_loss: 0.9396
# Epoch 18/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 147s 873ms/step - accuracy: 0.6472 - loss: 1.5286 - val_accuracy: 0.9013 - val_loss: 0.9107
# Epoch 19/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 147s 873ms/step - accuracy: 0.6357 - loss: 1.5869 - val_accuracy: 0.8829 - val_loss: 0.9803
# Epoch 20/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 147s 873ms/step - accuracy: 0.6357 - loss: 1.5634 - val_accuracy: 0.8838 - val_loss: 0.9725
# Epoch 21/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 147s 873ms/step - accuracy: 0.6457 - loss: 1.5557 - val_accuracy: 0.8503 - val_loss: 1.0113
# Epoch 22/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 147s 873ms/step - accuracy: 0.6509 - loss: 1.5025 - val_accuracy: 0.9030 - val_loss: 0.8389
# Epoch 23/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 148s 873ms/step - accuracy: 0.6511 - loss: 1.5576 - val_accuracy: 0.8746 - val_loss: 0.9446
# Epoch 24/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 148s 873ms/step - accuracy: 0.6415 - loss: 1.5348 - val_accuracy: 0.8554 - val_loss: 0.9862
# Epoch 25/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 148s 873ms/step - accuracy: 0.6441 - loss: 1.5000 - val_accuracy: 0.8746 - val_loss: 0.9101
# Epoch 26/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 148s 873ms/step - accuracy: 0.6459 - loss: 1.5032 - val_accuracy: 0.8980 - val_loss: 0.8868
# Epoch 27/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 148s 874ms/step - accuracy: 0.6533 - loss: 1.4936 - val_accuracy: 0.8211 - val_loss: 1.0263
# Epoch 28/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 148s 874ms/step - accuracy: 0.6445 - loss: 1.5151 - val_accuracy: 0.8896 - val_loss: 0.8833
# Epoch 29/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 147s 873ms/step - accuracy: 0.6423 - loss: 1.5067 - val_accuracy: 0.8938 - val_loss: 0.8891
# Epoch 30/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 148s 873ms/step - accuracy: 0.6476 - loss: 1.4846 - val_accuracy: 0.8972 - val_loss: 0.9017
# Epoch 31/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 148s 873ms/step - accuracy: 0.6535 - loss: 1.5066 - val_accuracy: 0.9214 - val_loss: 0.8602
# Epoch 32/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 148s 873ms/step - accuracy: 0.6478 - loss: 1.4837 - val_accuracy: 0.9114 - val_loss: 0.8620
# Epoch 33/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 147s 873ms/step - accuracy: 0.6561 - loss: 1.4589 - val_accuracy: 0.8378 - val_loss: 0.9520
# Epoch 34/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 148s 873ms/step - accuracy: 0.6370 - loss: 1.5186 - val_accuracy: 0.9055 - val_loss: 0.8913
# Epoch 35/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 148s 874ms/step - accuracy: 0.6439 - loss: 1.4990 - val_accuracy: 0.9214 - val_loss: 0.8816
# Epoch 36/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 148s 873ms/step - accuracy: 0.6452 - loss: 1.4818 - val_accuracy: 0.9306 - val_loss: 0.8226
# Final validation accuracy: 93.39%

# %%
metadata[MODEL_NAME] = (
    round(history['accuracy'][-1] * 100, 2),
    round(max(history['val_accuracy']) * 100, 2),
    history
)

with open(METADATA_FILE, 'wb') as f:
    pickle.dump(metadata, f)

# %% [markdown]
# ## Apply Fine Tuning

# %%
TRANSFER_MODEL_NAME = model_filename
SUPERNET_NAME = 'convnext_large'

# Re-load the model after transfer learning
if IS_COLAB:
    ft_model = tfk.models.load_model(TRANSFER_MODEL_NAME)
else:
    ft_model = tfk.models.load_model('/kaggle/working/'+ TRANSFER_MODEL_NAME)

# Display a summary of the model architecture
ft_model.summary(expand_nested=True)

# Display model architecture with layer shapes and trainable parameters
# tfk.utils.plot_model(ft_model, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)

print("Number of layers in the net: ", len(ft_model.layers))
print("Number of layers in the supernet: ", len(ft_model.get_layer(SUPERNET_NAME).layers))
# Out:
# Model: "CNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ augmentation (Sequential)       │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ random_flip_1 (RandomFlip) │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ random_translation_3       │ (None, 96, 96, 3)      │             0 │
# │ (RandomTranslation)             │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ random_rotation_1          │ (None, 96, 96, 3)      │             0 │
# │ (RandomRotation)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ random_zoom_1 (RandomZoom) │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ convnext_large (Functional)     │ (None, 3, 3, 1536)     │   196,230,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ input_layer (InputLayer)   │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 96, 96, 3)      │             0 │
# │ convnext_large_prestem_normali… │                        │               │
# │ (Normalization)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ convnext_large_stem        │ (None, 24, 24, 192)    │         9,792 │
# │ (Sequential)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │       └                         │ (None, 24, 24, 192)    │         9,408 │
# │ convnext_large_stem_conv        │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │       └                         │ (None, 24, 24, 192)    │           384 │
# │ convnext_large_stem_layernorm   │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 192)    │         9,600 │
# │ convnext_large_stage_0_block_0… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 192)    │           384 │
# │ convnext_large_stage_0_block_0… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 768)    │       148,224 │
# │ convnext_large_stage_0_block_0… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 768)    │             0 │
# │ convnext_large_stage_0_block_0… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 192)    │       147,648 │
# │ convnext_large_stage_0_block_0… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 192)    │           192 │
# │ convnext_large_stage_0_block_0… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 192)    │             0 │
# │ convnext_large_stage_0_block_0… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 192)    │         9,600 │
# │ convnext_large_stage_0_block_1… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 192)    │           384 │
# │ convnext_large_stage_0_block_1… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 768)    │       148,224 │
# │ convnext_large_stage_0_block_1… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 768)    │             0 │
# │ convnext_large_stage_0_block_1… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 192)    │       147,648 │
# │ convnext_large_stage_0_block_1… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 192)    │           192 │
# │ convnext_large_stage_0_block_1… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 192)    │             0 │
# │ convnext_large_stage_0_block_1… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 192)    │         9,600 │
# │ convnext_large_stage_0_block_2… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 192)    │           384 │
# │ convnext_large_stage_0_block_2… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 768)    │       148,224 │
# │ convnext_large_stage_0_block_2… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 768)    │             0 │
# │ convnext_large_stage_0_block_2… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 192)    │       147,648 │
# │ convnext_large_stage_0_block_2… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 192)    │           192 │
# │ convnext_large_stage_0_block_2… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 192)    │             0 │
# │ convnext_large_stage_0_block_2… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 384)    │       295,680 │
# │ convnext_large_downsampling_bl… │                        │               │
# │ (Sequential)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │       └                         │ (None, 24, 24, 192)    │           384 │
# │ convnext_large_downsampling_la… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │       └                         │ (None, 12, 12, 384)    │       295,296 │
# │ convnext_large_downsampling_co… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 384)    │        19,200 │
# │ convnext_large_stage_1_block_0… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 384)    │           768 │
# │ convnext_large_stage_1_block_0… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 1536)   │       591,360 │
# │ convnext_large_stage_1_block_0… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 1536)   │             0 │
# │ convnext_large_stage_1_block_0… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 384)    │       590,208 │
# │ convnext_large_stage_1_block_0… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 384)    │           384 │
# │ convnext_large_stage_1_block_0… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 384)    │             0 │
# │ convnext_large_stage_1_block_0… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 384)    │        19,200 │
# │ convnext_large_stage_1_block_1… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 384)    │           768 │
# │ convnext_large_stage_1_block_1… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 1536)   │       591,360 │
# │ convnext_large_stage_1_block_1… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 1536)   │             0 │
# │ convnext_large_stage_1_block_1… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 384)    │       590,208 │
# │ convnext_large_stage_1_block_1… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 384)    │           384 │
# │ convnext_large_stage_1_block_1… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 384)    │             0 │
# │ convnext_large_stage_1_block_1… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 384)    │        19,200 │
# │ convnext_large_stage_1_block_2… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 384)    │           768 │
# │ convnext_large_stage_1_block_2… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 1536)   │       591,360 │
# │ convnext_large_stage_1_block_2… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 1536)   │             0 │
# │ convnext_large_stage_1_block_2… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 384)    │       590,208 │
# │ convnext_large_stage_1_block_2… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 384)    │           384 │
# │ convnext_large_stage_1_block_2… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 384)    │             0 │
# │ convnext_large_stage_1_block_2… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │     1,181,184 │
# │ convnext_large_downsampling_bl… │                        │               │
# │ (Sequential)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │       └                         │ (None, 12, 12, 384)    │           768 │
# │ convnext_large_downsampling_la… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │       └                         │ (None, 6, 6, 768)      │     1,180,416 │
# │ convnext_large_downsampling_co… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │        38,400 │
# │ convnext_large_stage_2_block_0… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │         1,536 │
# │ convnext_large_stage_2_block_0… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │     2,362,368 │
# │ convnext_large_stage_2_block_0… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │             0 │
# │ convnext_large_stage_2_block_0… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │     2,360,064 │
# │ convnext_large_stage_2_block_0… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │           768 │
# │ convnext_large_stage_2_block_0… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │             0 │
# │ convnext_large_stage_2_block_0… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │        38,400 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │         1,536 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │     2,362,368 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │             0 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │     2,360,064 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │           768 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │             0 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │        38,400 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │         1,536 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │     2,362,368 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │             0 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │     2,360,064 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │           768 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │             0 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │        38,400 │
# │ convnext_large_stage_2_block_3… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │         1,536 │
# │ convnext_large_stage_2_block_3… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │     2,362,368 │
# │ convnext_large_stage_2_block_3… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │             0 │
# │ convnext_large_stage_2_block_3… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │     2,360,064 │
# │ convnext_large_stage_2_block_3… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │           768 │
# │ convnext_large_stage_2_block_3… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │             0 │
# │ convnext_large_stage_2_block_3… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │        38,400 │
# │ convnext_large_stage_2_block_4… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │         1,536 │
# │ convnext_large_stage_2_block_4… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │     2,362,368 │
# │ convnext_large_stage_2_block_4… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │             0 │
# │ convnext_large_stage_2_block_4… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │     2,360,064 │
# │ convnext_large_stage_2_block_4… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │           768 │
# │ convnext_large_stage_2_block_4… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │             0 │
# │ convnext_large_stage_2_block_4… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │        38,400 │
# │ convnext_large_stage_2_block_5… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │         1,536 │
# │ convnext_large_stage_2_block_5… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │     2,362,368 │
# │ convnext_large_stage_2_block_5… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │             0 │
# │ convnext_large_stage_2_block_5… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │     2,360,064 │
# │ convnext_large_stage_2_block_5… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │           768 │
# │ convnext_large_stage_2_block_5… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │             0 │
# │ convnext_large_stage_2_block_5… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │        38,400 │
# │ convnext_large_stage_2_block_6… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │         1,536 │
# │ convnext_large_stage_2_block_6… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │     2,362,368 │
# │ convnext_large_stage_2_block_6… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │             0 │
# │ convnext_large_stage_2_block_6… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │     2,360,064 │
# │ convnext_large_stage_2_block_6… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │           768 │
# │ convnext_large_stage_2_block_6… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │             0 │
# │ convnext_large_stage_2_block_6… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │        38,400 │
# │ convnext_large_stage_2_block_7… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │         1,536 │
# │ convnext_large_stage_2_block_7… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │     2,362,368 │
# │ convnext_large_stage_2_block_7… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │             0 │
# │ convnext_large_stage_2_block_7… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │     2,360,064 │
# │ convnext_large_stage_2_block_7… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │           768 │
# │ convnext_large_stage_2_block_7… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │             0 │
# │ convnext_large_stage_2_block_7… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │        38,400 │
# │ convnext_large_stage_2_block_8… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │         1,536 │
# │ convnext_large_stage_2_block_8… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │     2,362,368 │
# │ convnext_large_stage_2_block_8… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │             0 │
# │ convnext_large_stage_2_block_8… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │     2,360,064 │
# │ convnext_large_stage_2_block_8… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │           768 │
# │ convnext_large_stage_2_block_8… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │             0 │
# │ convnext_large_stage_2_block_8… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │        38,400 │
# │ convnext_large_stage_2_block_9… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │         1,536 │
# │ convnext_large_stage_2_block_9… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │     2,362,368 │
# │ convnext_large_stage_2_block_9… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │             0 │
# │ convnext_large_stage_2_block_9… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │     2,360,064 │
# │ convnext_large_stage_2_block_9… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │           768 │
# │ convnext_large_stage_2_block_9… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │             0 │
# │ convnext_large_stage_2_block_9… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │        38,400 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │         1,536 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │     2,362,368 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │             0 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │     2,360,064 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │           768 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │             0 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │        38,400 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │         1,536 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │     2,362,368 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │             0 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │     2,360,064 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │           768 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │             0 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │        38,400 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │         1,536 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │     2,362,368 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │             0 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │     2,360,064 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │           768 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │             0 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │        38,400 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │         1,536 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │     2,362,368 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │             0 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │     2,360,064 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │           768 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │             0 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │        38,400 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (Conv2D)                        │                        │               │
# ...
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │        38,400 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │         1,536 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │     2,362,368 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │             0 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │     2,360,064 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │           768 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │             0 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │        38,400 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │         1,536 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │     2,362,368 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │             0 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │     2,360,064 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │           768 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │             0 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │        38,400 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │         1,536 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │     2,362,368 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │             0 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │     2,360,064 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │           768 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │             0 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 1536)     │     4,721,664 │
# │ convnext_large_downsampling_bl… │                        │               │
# │ (Sequential)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │       └                         │ (None, 6, 6, 768)      │         1,536 │
# │ convnext_large_downsampling_la… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │       └                         │ (None, 3, 3, 1536)     │     4,720,128 │
# │ convnext_large_downsampling_co… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 1536)     │        76,800 │
# │ convnext_large_stage_3_block_0… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 1536)     │         3,072 │
# │ convnext_large_stage_3_block_0… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 6144)     │     9,443,328 │
# │ convnext_large_stage_3_block_0… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 6144)     │             0 │
# │ convnext_large_stage_3_block_0… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 1536)     │     9,438,720 │
# │ convnext_large_stage_3_block_0… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 1536)     │         1,536 │
# │ convnext_large_stage_3_block_0… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 1536)     │             0 │
# │ convnext_large_stage_3_block_0… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 1536)     │        76,800 │
# │ convnext_large_stage_3_block_1… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 1536)     │         3,072 │
# │ convnext_large_stage_3_block_1… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 6144)     │     9,443,328 │
# │ convnext_large_stage_3_block_1… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 6144)     │             0 │
# │ convnext_large_stage_3_block_1… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 1536)     │     9,438,720 │
# │ convnext_large_stage_3_block_1… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 1536)     │         1,536 │
# │ convnext_large_stage_3_block_1… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 1536)     │             0 │
# │ convnext_large_stage_3_block_1… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 1536)     │        76,800 │
# │ convnext_large_stage_3_block_2… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 1536)     │         3,072 │
# │ convnext_large_stage_3_block_2… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 6144)     │     9,443,328 │
# │ convnext_large_stage_3_block_2… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 6144)     │             0 │
# │ convnext_large_stage_3_block_2… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 1536)     │     9,438,720 │
# │ convnext_large_stage_3_block_2… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 1536)     │         1,536 │
# │ convnext_large_stage_3_block_2… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 1536)     │             0 │
# │ convnext_large_stage_3_block_2… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ layer_normalization        │ (None, 3, 3, 1536)     │         3,072 │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 13824)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 13824)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense1 (Dense)                  │ (None, 1024)           │    14,156,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ actdense1 (Activation)          │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense2 (Dense)                  │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ actdense2 (Activation)          │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 8)              │         8,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ softmax (Activation)            │ (None, 8)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 241,874,138 (922.68 MB)
#  Trainable params: 15,214,600 (58.04 MB)
#  Non-trainable params: 196,230,336 (748.56 MB)
#  Optimizer params: 30,429,202 (116.08 MB)
# Number of layers in the net:  13
# Number of layers in the supernet:  259

# %%
# Set the supernet model layers as trainable
ft_model.get_layer(SUPERNET_NAME).trainable = True

# Set all MobileNetV3Small layers as non-trainable
for layer in ft_model.get_layer(SUPERNET_NAME).layers:
    layer.trainable = False

# Enable training only for Conv2D and DepthwiseConv2D layers
for i, layer in enumerate(ft_model.get_layer(SUPERNET_NAME).layers):
    if isinstance(layer, tfk.layers.Conv2D) or isinstance(layer, tfk.layers.DepthwiseConv2D):
        layer.trainable = True
        print(i, layer.name, type(layer).__name__, layer.trainable)
# Out:
# 3 convnext_large_stage_0_block_0_depthwise_conv Conv2D True
# 10 convnext_large_stage_0_block_1_depthwise_conv Conv2D True
# 17 convnext_large_stage_0_block_2_depthwise_conv Conv2D True
# 25 convnext_large_stage_1_block_0_depthwise_conv Conv2D True
# 32 convnext_large_stage_1_block_1_depthwise_conv Conv2D True
# 39 convnext_large_stage_1_block_2_depthwise_conv Conv2D True
# 47 convnext_large_stage_2_block_0_depthwise_conv Conv2D True
# 54 convnext_large_stage_2_block_1_depthwise_conv Conv2D True
# 61 convnext_large_stage_2_block_2_depthwise_conv Conv2D True
# 68 convnext_large_stage_2_block_3_depthwise_conv Conv2D True
# 75 convnext_large_stage_2_block_4_depthwise_conv Conv2D True
# 82 convnext_large_stage_2_block_5_depthwise_conv Conv2D True
# 89 convnext_large_stage_2_block_6_depthwise_conv Conv2D True
# 96 convnext_large_stage_2_block_7_depthwise_conv Conv2D True
# 103 convnext_large_stage_2_block_8_depthwise_conv Conv2D True
# 110 convnext_large_stage_2_block_9_depthwise_conv Conv2D True
# 117 convnext_large_stage_2_block_10_depthwise_conv Conv2D True
# 124 convnext_large_stage_2_block_11_depthwise_conv Conv2D True
# 131 convnext_large_stage_2_block_12_depthwise_conv Conv2D True
# 138 convnext_large_stage_2_block_13_depthwise_conv Conv2D True
# 145 convnext_large_stage_2_block_14_depthwise_conv Conv2D True
# 152 convnext_large_stage_2_block_15_depthwise_conv Conv2D True
# 159 convnext_large_stage_2_block_16_depthwise_conv Conv2D True
# 166 convnext_large_stage_2_block_17_depthwise_conv Conv2D True
# 173 convnext_large_stage_2_block_18_depthwise_conv Conv2D True
# 180 convnext_large_stage_2_block_19_depthwise_conv Conv2D True
# 187 convnext_large_stage_2_block_20_depthwise_conv Conv2D True
# 194 convnext_large_stage_2_block_21_depthwise_conv Conv2D True
# 201 convnext_large_stage_2_block_22_depthwise_conv Conv2D True
# 208 convnext_large_stage_2_block_23_depthwise_conv Conv2D True
# 215 convnext_large_stage_2_block_24_depthwise_conv Conv2D True
# 222 convnext_large_stage_2_block_25_depthwise_conv Conv2D True
# 229 convnext_large_stage_2_block_26_depthwise_conv Conv2D True
# 237 convnext_large_stage_3_block_0_depthwise_conv Conv2D True
# 244 convnext_large_stage_3_block_1_depthwise_conv Conv2D True
# 251 convnext_large_stage_3_block_2_depthwise_conv Conv2D True

# %% [markdown]
# ##Fine-Tuning model parameters

# %%
# Number of layers freozen in the super net
FT_FREEZE_LAYERS = 0

#Apply a low learning rate for fine-tuning
FT_LEARNING_RATE = 5e-5

# %%
# Set the first N layers as non-trainable
for i, layer in enumerate(ft_model.get_layer(SUPERNET_NAME).layers[:FT_FREEZE_LAYERS]):
    layer.trainable = False

# Print layer indices, names, and trainability status
for i, layer in enumerate(ft_model.get_layer(SUPERNET_NAME).layers):
    print(i, layer.name, layer.trainable)

# Display a summary of the model architecture
ft_model.summary(expand_nested=True)

# Display model architecture with layer shapes and trainable parameters
# tfk.utils.plot_model(ft_model, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# 0 input_layer False
# 1 convnext_large_prestem_normalization False
# 2 convnext_large_stem False
# 3 convnext_large_stage_0_block_0_depthwise_conv True
# 4 convnext_large_stage_0_block_0_layernorm False
# 5 convnext_large_stage_0_block_0_pointwise_conv_1 False
# 6 convnext_large_stage_0_block_0_gelu False
# 7 convnext_large_stage_0_block_0_pointwise_conv_2 False
# 8 convnext_large_stage_0_block_0_layer_scale False
# 9 convnext_large_stage_0_block_0_identity False
# 10 convnext_large_stage_0_block_1_depthwise_conv True
# 11 convnext_large_stage_0_block_1_layernorm False
# 12 convnext_large_stage_0_block_1_pointwise_conv_1 False
# 13 convnext_large_stage_0_block_1_gelu False
# 14 convnext_large_stage_0_block_1_pointwise_conv_2 False
# 15 convnext_large_stage_0_block_1_layer_scale False
# 16 convnext_large_stage_0_block_1_identity False
# 17 convnext_large_stage_0_block_2_depthwise_conv True
# 18 convnext_large_stage_0_block_2_layernorm False
# 19 convnext_large_stage_0_block_2_pointwise_conv_1 False
# 20 convnext_large_stage_0_block_2_gelu False
# 21 convnext_large_stage_0_block_2_pointwise_conv_2 False
# 22 convnext_large_stage_0_block_2_layer_scale False
# 23 convnext_large_stage_0_block_2_identity False
# 24 convnext_large_downsampling_block_0 False
# 25 convnext_large_stage_1_block_0_depthwise_conv True
# 26 convnext_large_stage_1_block_0_layernorm False
# 27 convnext_large_stage_1_block_0_pointwise_conv_1 False
# 28 convnext_large_stage_1_block_0_gelu False
# 29 convnext_large_stage_1_block_0_pointwise_conv_2 False
# 30 convnext_large_stage_1_block_0_layer_scale False
# 31 convnext_large_stage_1_block_0_identity False
# 32 convnext_large_stage_1_block_1_depthwise_conv True
# 33 convnext_large_stage_1_block_1_layernorm False
# 34 convnext_large_stage_1_block_1_pointwise_conv_1 False
# 35 convnext_large_stage_1_block_1_gelu False
# 36 convnext_large_stage_1_block_1_pointwise_conv_2 False
# 37 convnext_large_stage_1_block_1_layer_scale False
# 38 convnext_large_stage_1_block_1_identity False
# 39 convnext_large_stage_1_block_2_depthwise_conv True
# 40 convnext_large_stage_1_block_2_layernorm False
# 41 convnext_large_stage_1_block_2_pointwise_conv_1 False
# 42 convnext_large_stage_1_block_2_gelu False
# 43 convnext_large_stage_1_block_2_pointwise_conv_2 False
# 44 convnext_large_stage_1_block_2_layer_scale False
# 45 convnext_large_stage_1_block_2_identity False
# 46 convnext_large_downsampling_block_1 False
# 47 convnext_large_stage_2_block_0_depthwise_conv True
# 48 convnext_large_stage_2_block_0_layernorm False
# 49 convnext_large_stage_2_block_0_pointwise_conv_1 False
# 50 convnext_large_stage_2_block_0_gelu False
# 51 convnext_large_stage_2_block_0_pointwise_conv_2 False
# 52 convnext_large_stage_2_block_0_layer_scale False
# 53 convnext_large_stage_2_block_0_identity False
# 54 convnext_large_stage_2_block_1_depthwise_conv True
# 55 convnext_large_stage_2_block_1_layernorm False
# 56 convnext_large_stage_2_block_1_pointwise_conv_1 False
# 57 convnext_large_stage_2_block_1_gelu False
# 58 convnext_large_stage_2_block_1_pointwise_conv_2 False
# 59 convnext_large_stage_2_block_1_layer_scale False
# 60 convnext_large_stage_2_block_1_identity False
# 61 convnext_large_stage_2_block_2_depthwise_conv True
# 62 convnext_large_stage_2_block_2_layernorm False
# 63 convnext_large_stage_2_block_2_pointwise_conv_1 False
# 64 convnext_large_stage_2_block_2_gelu False
# 65 convnext_large_stage_2_block_2_pointwise_conv_2 False
# 66 convnext_large_stage_2_block_2_layer_scale False
# 67 convnext_large_stage_2_block_2_identity False
# 68 convnext_large_stage_2_block_3_depthwise_conv True
# 69 convnext_large_stage_2_block_3_layernorm False
# 70 convnext_large_stage_2_block_3_pointwise_conv_1 False
# 71 convnext_large_stage_2_block_3_gelu False
# 72 convnext_large_stage_2_block_3_pointwise_conv_2 False
# 73 convnext_large_stage_2_block_3_layer_scale False
# 74 convnext_large_stage_2_block_3_identity False
# 75 convnext_large_stage_2_block_4_depthwise_conv True
# 76 convnext_large_stage_2_block_4_layernorm False
# 77 convnext_large_stage_2_block_4_pointwise_conv_1 False
# 78 convnext_large_stage_2_block_4_gelu False
# 79 convnext_large_stage_2_block_4_pointwise_conv_2 False
# 80 convnext_large_stage_2_block_4_layer_scale False
# 81 convnext_large_stage_2_block_4_identity False
# 82 convnext_large_stage_2_block_5_depthwise_conv True
# 83 convnext_large_stage_2_block_5_layernorm False
# 84 convnext_large_stage_2_block_5_pointwise_conv_1 False
# 85 convnext_large_stage_2_block_5_gelu False
# 86 convnext_large_stage_2_block_5_pointwise_conv_2 False
# 87 convnext_large_stage_2_block_5_layer_scale False
# 88 convnext_large_stage_2_block_5_identity False
# 89 convnext_large_stage_2_block_6_depthwise_conv True
# 90 convnext_large_stage_2_block_6_layernorm False
# 91 convnext_large_stage_2_block_6_pointwise_conv_1 False
# 92 convnext_large_stage_2_block_6_gelu False
# 93 convnext_large_stage_2_block_6_pointwise_conv_2 False
# 94 convnext_large_stage_2_block_6_layer_scale False
# 95 convnext_large_stage_2_block_6_identity False
# 96 convnext_large_stage_2_block_7_depthwise_conv True
# 97 convnext_large_stage_2_block_7_layernorm False
# 98 convnext_large_stage_2_block_7_pointwise_conv_1 False
# 99 convnext_large_stage_2_block_7_gelu False
# 100 convnext_large_stage_2_block_7_pointwise_conv_2 False
# 101 convnext_large_stage_2_block_7_layer_scale False
# 102 convnext_large_stage_2_block_7_identity False
# 103 convnext_large_stage_2_block_8_depthwise_conv True
# 104 convnext_large_stage_2_block_8_layernorm False
# 105 convnext_large_stage_2_block_8_pointwise_conv_1 False
# 106 convnext_large_stage_2_block_8_gelu False
# 107 convnext_large_stage_2_block_8_pointwise_conv_2 False
# 108 convnext_large_stage_2_block_8_layer_scale False
# 109 convnext_large_stage_2_block_8_identity False
# 110 convnext_large_stage_2_block_9_depthwise_conv True
# 111 convnext_large_stage_2_block_9_layernorm False
# 112 convnext_large_stage_2_block_9_pointwise_conv_1 False
# 113 convnext_large_stage_2_block_9_gelu False
# 114 convnext_large_stage_2_block_9_pointwise_conv_2 False
# 115 convnext_large_stage_2_block_9_layer_scale False
# 116 convnext_large_stage_2_block_9_identity False
# 117 convnext_large_stage_2_block_10_depthwise_conv True
# 118 convnext_large_stage_2_block_10_layernorm False
# 119 convnext_large_stage_2_block_10_pointwise_conv_1 False
# 120 convnext_large_stage_2_block_10_gelu False
# 121 convnext_large_stage_2_block_10_pointwise_conv_2 False
# 122 convnext_large_stage_2_block_10_layer_scale False
# 123 convnext_large_stage_2_block_10_identity False
# 124 convnext_large_stage_2_block_11_depthwise_conv True
# 125 convnext_large_stage_2_block_11_layernorm False
# 126 convnext_large_stage_2_block_11_pointwise_conv_1 False
# 127 convnext_large_stage_2_block_11_gelu False
# 128 convnext_large_stage_2_block_11_pointwise_conv_2 False
# 129 convnext_large_stage_2_block_11_layer_scale False
# 130 convnext_large_stage_2_block_11_identity False
# 131 convnext_large_stage_2_block_12_depthwise_conv True
# 132 convnext_large_stage_2_block_12_layernorm False
# 133 convnext_large_stage_2_block_12_pointwise_conv_1 False
# 134 convnext_large_stage_2_block_12_gelu False
# 135 convnext_large_stage_2_block_12_pointwise_conv_2 False
# 136 convnext_large_stage_2_block_12_layer_scale False
# 137 convnext_large_stage_2_block_12_identity False
# 138 convnext_large_stage_2_block_13_depthwise_conv True
# 139 convnext_large_stage_2_block_13_layernorm False
# 140 convnext_large_stage_2_block_13_pointwise_conv_1 False
# 141 convnext_large_stage_2_block_13_gelu False
# 142 convnext_large_stage_2_block_13_pointwise_conv_2 False
# 143 convnext_large_stage_2_block_13_layer_scale False
# 144 convnext_large_stage_2_block_13_identity False
# 145 convnext_large_stage_2_block_14_depthwise_conv True
# 146 convnext_large_stage_2_block_14_layernorm False
# 147 convnext_large_stage_2_block_14_pointwise_conv_1 False
# 148 convnext_large_stage_2_block_14_gelu False
# 149 convnext_large_stage_2_block_14_pointwise_conv_2 False
# 150 convnext_large_stage_2_block_14_layer_scale False
# 151 convnext_large_stage_2_block_14_identity False
# 152 convnext_large_stage_2_block_15_depthwise_conv True
# 153 convnext_large_stage_2_block_15_layernorm False
# 154 convnext_large_stage_2_block_15_pointwise_conv_1 False
# 155 convnext_large_stage_2_block_15_gelu False
# 156 convnext_large_stage_2_block_15_pointwise_conv_2 False
# 157 convnext_large_stage_2_block_15_layer_scale False
# 158 convnext_large_stage_2_block_15_identity False
# 159 convnext_large_stage_2_block_16_depthwise_conv True
# 160 convnext_large_stage_2_block_16_layernorm False
# 161 convnext_large_stage_2_block_16_pointwise_conv_1 False
# 162 convnext_large_stage_2_block_16_gelu False
# 163 convnext_large_stage_2_block_16_pointwise_conv_2 False
# 164 convnext_large_stage_2_block_16_layer_scale False
# 165 convnext_large_stage_2_block_16_identity False
# 166 convnext_large_stage_2_block_17_depthwise_conv True
# 167 convnext_large_stage_2_block_17_layernorm False
# 168 convnext_large_stage_2_block_17_pointwise_conv_1 False
# 169 convnext_large_stage_2_block_17_gelu False
# 170 convnext_large_stage_2_block_17_pointwise_conv_2 False
# 171 convnext_large_stage_2_block_17_layer_scale False
# 172 convnext_large_stage_2_block_17_identity False
# 173 convnext_large_stage_2_block_18_depthwise_conv True
# 174 convnext_large_stage_2_block_18_layernorm False
# 175 convnext_large_stage_2_block_18_pointwise_conv_1 False
# 176 convnext_large_stage_2_block_18_gelu False
# 177 convnext_large_stage_2_block_18_pointwise_conv_2 False
# 178 convnext_large_stage_2_block_18_layer_scale False
# 179 convnext_large_stage_2_block_18_identity False
# 180 convnext_large_stage_2_block_19_depthwise_conv True
# 181 convnext_large_stage_2_block_19_layernorm False
# 182 convnext_large_stage_2_block_19_pointwise_conv_1 False
# 183 convnext_large_stage_2_block_19_gelu False
# 184 convnext_large_stage_2_block_19_pointwise_conv_2 False
# 185 convnext_large_stage_2_block_19_layer_scale False
# 186 convnext_large_stage_2_block_19_identity False
# 187 convnext_large_stage_2_block_20_depthwise_conv True
# 188 convnext_large_stage_2_block_20_layernorm False
# 189 convnext_large_stage_2_block_20_pointwise_conv_1 False
# 190 convnext_large_stage_2_block_20_gelu False
# 191 convnext_large_stage_2_block_20_pointwise_conv_2 False
# 192 convnext_large_stage_2_block_20_layer_scale False
# 193 convnext_large_stage_2_block_20_identity False
# 194 convnext_large_stage_2_block_21_depthwise_conv True
# 195 convnext_large_stage_2_block_21_layernorm False
# 196 convnext_large_stage_2_block_21_pointwise_conv_1 False
# 197 convnext_large_stage_2_block_21_gelu False
# 198 convnext_large_stage_2_block_21_pointwise_conv_2 False
# 199 convnext_large_stage_2_block_21_layer_scale False
# 200 convnext_large_stage_2_block_21_identity False
# 201 convnext_large_stage_2_block_22_depthwise_conv True
# 202 convnext_large_stage_2_block_22_layernorm False
# 203 convnext_large_stage_2_block_22_pointwise_conv_1 False
# 204 convnext_large_stage_2_block_22_gelu False
# 205 convnext_large_stage_2_block_22_pointwise_conv_2 False
# 206 convnext_large_stage_2_block_22_layer_scale False
# 207 convnext_large_stage_2_block_22_identity False
# 208 convnext_large_stage_2_block_23_depthwise_conv True
# 209 convnext_large_stage_2_block_23_layernorm False
# 210 convnext_large_stage_2_block_23_pointwise_conv_1 False
# 211 convnext_large_stage_2_block_23_gelu False
# 212 convnext_large_stage_2_block_23_pointwise_conv_2 False
# 213 convnext_large_stage_2_block_23_layer_scale False
# 214 convnext_large_stage_2_block_23_identity False
# 215 convnext_large_stage_2_block_24_depthwise_conv True
# 216 convnext_large_stage_2_block_24_layernorm False
# 217 convnext_large_stage_2_block_24_pointwise_conv_1 False
# 218 convnext_large_stage_2_block_24_gelu False
# 219 convnext_large_stage_2_block_24_pointwise_conv_2 False
# 220 convnext_large_stage_2_block_24_layer_scale False
# 221 convnext_large_stage_2_block_24_identity False
# 222 convnext_large_stage_2_block_25_depthwise_conv True
# 223 convnext_large_stage_2_block_25_layernorm False
# 224 convnext_large_stage_2_block_25_pointwise_conv_1 False
# 225 convnext_large_stage_2_block_25_gelu False
# 226 convnext_large_stage_2_block_25_pointwise_conv_2 False
# 227 convnext_large_stage_2_block_25_layer_scale False
# 228 convnext_large_stage_2_block_25_identity False
# 229 convnext_large_stage_2_block_26_depthwise_conv True
# 230 convnext_large_stage_2_block_26_layernorm False
# 231 convnext_large_stage_2_block_26_pointwise_conv_1 False
# 232 convnext_large_stage_2_block_26_gelu False
# 233 convnext_large_stage_2_block_26_pointwise_conv_2 False
# 234 convnext_large_stage_2_block_26_layer_scale False
# 235 convnext_large_stage_2_block_26_identity False
# 236 convnext_large_downsampling_block_2 False
# 237 convnext_large_stage_3_block_0_depthwise_conv True
# 238 convnext_large_stage_3_block_0_layernorm False
# 239 convnext_large_stage_3_block_0_pointwise_conv_1 False
# 240 convnext_large_stage_3_block_0_gelu False
# 241 convnext_large_stage_3_block_0_pointwise_conv_2 False
# 242 convnext_large_stage_3_block_0_layer_scale False
# 243 convnext_large_stage_3_block_0_identity False
# 244 convnext_large_stage_3_block_1_depthwise_conv True
# 245 convnext_large_stage_3_block_1_layernorm False
# 246 convnext_large_stage_3_block_1_pointwise_conv_1 False
# 247 convnext_large_stage_3_block_1_gelu False
# 248 convnext_large_stage_3_block_1_pointwise_conv_2 False
# 249 convnext_large_stage_3_block_1_layer_scale False
# 250 convnext_large_stage_3_block_1_identity False
# 251 convnext_large_stage_3_block_2_depthwise_conv True
# 252 convnext_large_stage_3_block_2_layernorm False
# 253 convnext_large_stage_3_block_2_pointwise_conv_1 False
# 254 convnext_large_stage_3_block_2_gelu False
# 255 convnext_large_stage_3_block_2_pointwise_conv_2 False
# 256 convnext_large_stage_3_block_2_layer_scale False
# 257 convnext_large_stage_3_block_2_identity False
# 258 layer_normalization False
# Model: "CNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ augmentation (Sequential)       │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ random_flip_1 (RandomFlip) │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ random_translation_3       │ (None, 96, 96, 3)      │             0 │
# │ (RandomTranslation)             │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ random_rotation_1          │ (None, 96, 96, 3)      │             0 │
# │ (RandomRotation)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ random_zoom_1 (RandomZoom) │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ convnext_large (Functional)     │ (None, 3, 3, 1536)     │   196,230,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ input_layer (InputLayer)   │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 96, 96, 3)      │             0 │
# │ convnext_large_prestem_normali… │                        │               │
# │ (Normalization)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ convnext_large_stem        │ (None, 24, 24, 192)    │         9,792 │
# │ (Sequential)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │       └                         │ (None, 24, 24, 192)    │         9,408 │
# │ convnext_large_stem_conv        │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │       └                         │ (None, 24, 24, 192)    │           384 │
# │ convnext_large_stem_layernorm   │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 192)    │         9,600 │
# │ convnext_large_stage_0_block_0… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 192)    │           384 │
# │ convnext_large_stage_0_block_0… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 768)    │       148,224 │
# │ convnext_large_stage_0_block_0… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 768)    │             0 │
# │ convnext_large_stage_0_block_0… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 192)    │       147,648 │
# │ convnext_large_stage_0_block_0… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 192)    │           192 │
# │ convnext_large_stage_0_block_0… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 192)    │             0 │
# │ convnext_large_stage_0_block_0… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 192)    │         9,600 │
# │ convnext_large_stage_0_block_1… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 192)    │           384 │
# │ convnext_large_stage_0_block_1… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 768)    │       148,224 │
# │ convnext_large_stage_0_block_1… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 768)    │             0 │
# │ convnext_large_stage_0_block_1… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 192)    │       147,648 │
# │ convnext_large_stage_0_block_1… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 192)    │           192 │
# │ convnext_large_stage_0_block_1… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 192)    │             0 │
# │ convnext_large_stage_0_block_1… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 192)    │         9,600 │
# │ convnext_large_stage_0_block_2… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 192)    │           384 │
# │ convnext_large_stage_0_block_2… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 768)    │       148,224 │
# │ convnext_large_stage_0_block_2… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 768)    │             0 │
# │ convnext_large_stage_0_block_2… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 192)    │       147,648 │
# │ convnext_large_stage_0_block_2… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 192)    │           192 │
# │ convnext_large_stage_0_block_2… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 24, 24, 192)    │             0 │
# │ convnext_large_stage_0_block_2… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 384)    │       295,680 │
# │ convnext_large_downsampling_bl… │                        │               │
# │ (Sequential)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │       └                         │ (None, 24, 24, 192)    │           384 │
# │ convnext_large_downsampling_la… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │       └                         │ (None, 12, 12, 384)    │       295,296 │
# │ convnext_large_downsampling_co… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 384)    │        19,200 │
# │ convnext_large_stage_1_block_0… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 384)    │           768 │
# │ convnext_large_stage_1_block_0… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 1536)   │       591,360 │
# │ convnext_large_stage_1_block_0… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 1536)   │             0 │
# │ convnext_large_stage_1_block_0… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 384)    │       590,208 │
# │ convnext_large_stage_1_block_0… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 384)    │           384 │
# │ convnext_large_stage_1_block_0… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 384)    │             0 │
# │ convnext_large_stage_1_block_0… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 384)    │        19,200 │
# │ convnext_large_stage_1_block_1… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 384)    │           768 │
# │ convnext_large_stage_1_block_1… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 1536)   │       591,360 │
# │ convnext_large_stage_1_block_1… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 1536)   │             0 │
# │ convnext_large_stage_1_block_1… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 384)    │       590,208 │
# │ convnext_large_stage_1_block_1… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 384)    │           384 │
# │ convnext_large_stage_1_block_1… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 384)    │             0 │
# │ convnext_large_stage_1_block_1… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 384)    │        19,200 │
# │ convnext_large_stage_1_block_2… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 384)    │           768 │
# │ convnext_large_stage_1_block_2… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 1536)   │       591,360 │
# │ convnext_large_stage_1_block_2… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 1536)   │             0 │
# │ convnext_large_stage_1_block_2… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 384)    │       590,208 │
# │ convnext_large_stage_1_block_2… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 384)    │           384 │
# │ convnext_large_stage_1_block_2… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 12, 12, 384)    │             0 │
# │ convnext_large_stage_1_block_2… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │     1,181,184 │
# │ convnext_large_downsampling_bl… │                        │               │
# │ (Sequential)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │       └                         │ (None, 12, 12, 384)    │           768 │
# │ convnext_large_downsampling_la… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │       └                         │ (None, 6, 6, 768)      │     1,180,416 │
# │ convnext_large_downsampling_co… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │        38,400 │
# │ convnext_large_stage_2_block_0… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │         1,536 │
# │ convnext_large_stage_2_block_0… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │     2,362,368 │
# │ convnext_large_stage_2_block_0… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │             0 │
# │ convnext_large_stage_2_block_0… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │     2,360,064 │
# │ convnext_large_stage_2_block_0… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │           768 │
# │ convnext_large_stage_2_block_0… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │             0 │
# │ convnext_large_stage_2_block_0… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │        38,400 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │         1,536 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │     2,362,368 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │             0 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │     2,360,064 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │           768 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │             0 │
# │ convnext_large_stage_2_block_1… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │        38,400 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │         1,536 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │     2,362,368 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │             0 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │     2,360,064 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │           768 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │             0 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │        38,400 │
# │ convnext_large_stage_2_block_3… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │         1,536 │
# │ convnext_large_stage_2_block_3… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │     2,362,368 │
# │ convnext_large_stage_2_block_3… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │             0 │
# │ convnext_large_stage_2_block_3… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │     2,360,064 │
# │ convnext_large_stage_2_block_3… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │           768 │
# │ convnext_large_stage_2_block_3… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │             0 │
# │ convnext_large_stage_2_block_3… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │        38,400 │
# │ convnext_large_stage_2_block_4… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │         1,536 │
# │ convnext_large_stage_2_block_4… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │     2,362,368 │
# │ convnext_large_stage_2_block_4… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │             0 │
# │ convnext_large_stage_2_block_4… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │     2,360,064 │
# │ convnext_large_stage_2_block_4… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │           768 │
# │ convnext_large_stage_2_block_4… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │             0 │
# │ convnext_large_stage_2_block_4… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │        38,400 │
# │ convnext_large_stage_2_block_5… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │         1,536 │
# │ convnext_large_stage_2_block_5… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │     2,362,368 │
# │ convnext_large_stage_2_block_5… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │             0 │
# │ convnext_large_stage_2_block_5… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │     2,360,064 │
# │ convnext_large_stage_2_block_5… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │           768 │
# │ convnext_large_stage_2_block_5… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │             0 │
# │ convnext_large_stage_2_block_5… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │        38,400 │
# │ convnext_large_stage_2_block_6… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │         1,536 │
# │ convnext_large_stage_2_block_6… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │     2,362,368 │
# │ convnext_large_stage_2_block_6… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │             0 │
# │ convnext_large_stage_2_block_6… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │     2,360,064 │
# │ convnext_large_stage_2_block_6… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │           768 │
# │ convnext_large_stage_2_block_6… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │             0 │
# │ convnext_large_stage_2_block_6… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │        38,400 │
# │ convnext_large_stage_2_block_7… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │         1,536 │
# │ convnext_large_stage_2_block_7… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │     2,362,368 │
# │ convnext_large_stage_2_block_7… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │             0 │
# │ convnext_large_stage_2_block_7… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │     2,360,064 │
# │ convnext_large_stage_2_block_7… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │           768 │
# │ convnext_large_stage_2_block_7… │                        │               │
# ...
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │        38,400 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │         1,536 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │     2,362,368 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │             0 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │     2,360,064 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │           768 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │             0 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │        38,400 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │         1,536 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │     2,362,368 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │             0 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │     2,360,064 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │           768 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │             0 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │        38,400 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │         1,536 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │     2,362,368 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 3072)     │             0 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │     2,360,064 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │           768 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 6, 6, 768)      │             0 │
# │ convnext_large_stage_2_block_2… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 1536)     │     4,721,664 │
# │ convnext_large_downsampling_bl… │                        │               │
# │ (Sequential)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │       └                         │ (None, 6, 6, 768)      │         1,536 │
# │ convnext_large_downsampling_la… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │       └                         │ (None, 3, 3, 1536)     │     4,720,128 │
# │ convnext_large_downsampling_co… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 1536)     │        76,800 │
# │ convnext_large_stage_3_block_0… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 1536)     │         3,072 │
# │ convnext_large_stage_3_block_0… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 6144)     │     9,443,328 │
# │ convnext_large_stage_3_block_0… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 6144)     │             0 │
# │ convnext_large_stage_3_block_0… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 1536)     │     9,438,720 │
# │ convnext_large_stage_3_block_0… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 1536)     │         1,536 │
# │ convnext_large_stage_3_block_0… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 1536)     │             0 │
# │ convnext_large_stage_3_block_0… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 1536)     │        76,800 │
# │ convnext_large_stage_3_block_1… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 1536)     │         3,072 │
# │ convnext_large_stage_3_block_1… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 6144)     │     9,443,328 │
# │ convnext_large_stage_3_block_1… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 6144)     │             0 │
# │ convnext_large_stage_3_block_1… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 1536)     │     9,438,720 │
# │ convnext_large_stage_3_block_1… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 1536)     │         1,536 │
# │ convnext_large_stage_3_block_1… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 1536)     │             0 │
# │ convnext_large_stage_3_block_1… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 1536)     │        76,800 │
# │ convnext_large_stage_3_block_2… │                        │               │
# │ (Conv2D)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 1536)     │         3,072 │
# │ convnext_large_stage_3_block_2… │                        │               │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 6144)     │     9,443,328 │
# │ convnext_large_stage_3_block_2… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 6144)     │             0 │
# │ convnext_large_stage_3_block_2… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 1536)     │     9,438,720 │
# │ convnext_large_stage_3_block_2… │                        │               │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 1536)     │         1,536 │
# │ convnext_large_stage_3_block_2… │                        │               │
# │ (LayerScale)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └                            │ (None, 3, 3, 1536)     │             0 │
# │ convnext_large_stage_3_block_2… │                        │               │
# │ (Activation)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ layer_normalization        │ (None, 3, 3, 1536)     │         3,072 │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 13824)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 13824)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense1 (Dense)                  │ (None, 1024)           │    14,156,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ actdense1 (Activation)          │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense2 (Dense)                  │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ actdense2 (Activation)          │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 8)              │         8,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ softmax (Activation)            │ (None, 8)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 241,874,138 (922.68 MB)
#  Trainable params: 16,568,200 (63.20 MB)
#  Non-trainable params: 194,876,736 (743.40 MB)
#  Optimizer params: 30,429,202 (116.08 MB)

# %%
ft_model.compile(
    loss=tfk.losses.CategoricalCrossentropy(),
    optimizer=tfk.optimizers.Adam(FT_LEARNING_RATE),
    metrics=['accuracy']
)

# %%
# Define the patience value for early stopping
patience = 20

# Create an EarlyStopping callback
early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=patience,
    restore_best_weights=True
)

# Store the callback in a list
callbacks = [early_stopping]

# %%
# Change this variable to change the name of the .keras file
FT_MODEL_NAME = 'FT_' + MODEL_NAME + '_freeze' + str(FT_FREEZE_LAYERS)

# Fine-tune the model
ft_history = ft_model.fit(
    x=X_train_augmented,
    y=y_train_augmented,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=(X_val, y_val),
    callbacks=callbacks,
    class_weight=class_weights_dict
).history

# Calculate and print the final validation accuracy
final_val_accuracy = round(max(ft_history['val_accuracy'])* 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')

# Save the trained model to a file with the accuracy included in the filename
ft_model_filename = 'CNN_'+FT_MODEL_NAME+'_'+str(final_val_accuracy)+'.keras'
ft_model.save(ft_model_filename)

# Delete the model to free up resources
del ft_model
# Out:
# Epoch 1/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 305s 2s/step - accuracy: 0.6777 - loss: 1.4510 - val_accuracy: 0.9323 - val_loss: 0.7329
# Epoch 2/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.7340 - loss: 1.2487 - val_accuracy: 0.9256 - val_loss: 0.6936
# Epoch 3/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.7440 - loss: 1.1924 - val_accuracy: 0.9273 - val_loss: 0.6592
# Epoch 4/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.7496 - loss: 1.1425 - val_accuracy: 0.9440 - val_loss: 0.6235
# Epoch 5/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.7674 - loss: 1.1065 - val_accuracy: 0.9348 - val_loss: 0.6154
# Epoch 6/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.7733 - loss: 1.0731 - val_accuracy: 0.9356 - val_loss: 0.6040
# Epoch 7/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.7902 - loss: 1.0326 - val_accuracy: 0.9523 - val_loss: 0.5714
# Epoch 8/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.7916 - loss: 1.0060 - val_accuracy: 0.9457 - val_loss: 0.5706
# Epoch 9/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.7994 - loss: 0.9726 - val_accuracy: 0.9490 - val_loss: 0.5698
# Epoch 10/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.8118 - loss: 0.9381 - val_accuracy: 0.9582 - val_loss: 0.5383
# Epoch 11/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.8210 - loss: 0.9125 - val_accuracy: 0.9515 - val_loss: 0.5416
# Epoch 12/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.8213 - loss: 0.9001 - val_accuracy: 0.9557 - val_loss: 0.5251
# Epoch 13/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.8266 - loss: 0.8790 - val_accuracy: 0.9590 - val_loss: 0.5196
# Epoch 14/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.8386 - loss: 0.8453 - val_accuracy: 0.9557 - val_loss: 0.5168
# Epoch 15/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.8353 - loss: 0.8483 - val_accuracy: 0.9599 - val_loss: 0.5054
# Epoch 16/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.8432 - loss: 0.8213 - val_accuracy: 0.9599 - val_loss: 0.4969
# Epoch 17/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.8526 - loss: 0.8081 - val_accuracy: 0.9590 - val_loss: 0.4998
# Epoch 18/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.8565 - loss: 0.7824 - val_accuracy: 0.9624 - val_loss: 0.4850
# Epoch 19/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.8655 - loss: 0.7515 - val_accuracy: 0.9582 - val_loss: 0.4885
# Epoch 20/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.8642 - loss: 0.7469 - val_accuracy: 0.9682 - val_loss: 0.4629
# Epoch 21/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.8615 - loss: 0.7553 - val_accuracy: 0.9582 - val_loss: 0.4827
# Epoch 22/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.8687 - loss: 0.7369 - val_accuracy: 0.9615 - val_loss: 0.4596
# Epoch 23/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.8741 - loss: 0.7075 - val_accuracy: 0.9632 - val_loss: 0.4629
# Epoch 24/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.8716 - loss: 0.7030 - val_accuracy: 0.9615 - val_loss: 0.4542
# Epoch 25/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.8794 - loss: 0.6945 - val_accuracy: 0.9640 - val_loss: 0.4480
# Epoch 26/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.8761 - loss: 0.6912 - val_accuracy: 0.9607 - val_loss: 0.4542
# Epoch 27/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.8890 - loss: 0.6609 - val_accuracy: 0.9649 - val_loss: 0.4364
# Epoch 28/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.8842 - loss: 0.6564 - val_accuracy: 0.9657 - val_loss: 0.4287
# Epoch 29/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.8834 - loss: 0.6658 - val_accuracy: 0.9691 - val_loss: 0.4188
# Epoch 30/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.8851 - loss: 0.6481 - val_accuracy: 0.9674 - val_loss: 0.4214
# Epoch 31/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.8870 - loss: 0.6398 - val_accuracy: 0.9615 - val_loss: 0.4312
# Epoch 32/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.8962 - loss: 0.6155 - val_accuracy: 0.9590 - val_loss: 0.4239
# Epoch 33/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.8965 - loss: 0.6139 - val_accuracy: 0.9590 - val_loss: 0.4319
# Epoch 34/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.8940 - loss: 0.5999 - val_accuracy: 0.9624 - val_loss: 0.4204
# Epoch 35/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.8953 - loss: 0.5926 - val_accuracy: 0.9632 - val_loss: 0.4067
# Epoch 36/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.9021 - loss: 0.5815 - val_accuracy: 0.9691 - val_loss: 0.3864
# Epoch 37/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.8998 - loss: 0.5737 - val_accuracy: 0.9624 - val_loss: 0.4018
# Epoch 38/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.8963 - loss: 0.5725 - val_accuracy: 0.9691 - val_loss: 0.3879
# Epoch 39/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.9030 - loss: 0.5548 - val_accuracy: 0.9666 - val_loss: 0.3802
# Epoch 40/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.9038 - loss: 0.5549 - val_accuracy: 0.9666 - val_loss: 0.3806
# Epoch 41/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.9060 - loss: 0.5426 - val_accuracy: 0.9666 - val_loss: 0.3732
# Epoch 42/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.9035 - loss: 0.5459 - val_accuracy: 0.9682 - val_loss: 0.3648
# Epoch 43/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.9115 - loss: 0.5229 - val_accuracy: 0.9674 - val_loss: 0.3631
# Epoch 44/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.9095 - loss: 0.5183 - val_accuracy: 0.9649 - val_loss: 0.3653
# Epoch 45/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.9141 - loss: 0.5011 - val_accuracy: 0.9691 - val_loss: 0.3566
# Epoch 46/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.9118 - loss: 0.5132 - val_accuracy: 0.9674 - val_loss: 0.3456
# Epoch 47/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.9201 - loss: 0.4842 - val_accuracy: 0.9666 - val_loss: 0.3474
# Epoch 48/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.9198 - loss: 0.4834 - val_accuracy: 0.9657 - val_loss: 0.3562
# Epoch 49/1000
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.9136 - loss: 0.4941 - val_accuracy: 0.9666 - val_loss: 0.3429
# Final validation accuracy: 96.91%

# %%
metadata[FT_MODEL_NAME] = (
    round(ft_history['accuracy'][-1] * 100, 2),
    round(max(ft_history['val_accuracy']) * 100, 2),
    ft_history
)

with open(METADATA_FILE, 'wb') as f:
    pickle.dump(metadata, f)

# %%
start_epoch = 0

metadata_copy = metadata.copy()

for name, (acc, val_acc, _) in metadata_copy.items():
    print(name + " train accuracy:", acc)
    print(name + " validation accuracy:", val_acc)

# Plot training and validation loss
plt.figure(figsize=(15, 6))
for name, (_, _, saved_history) in metadata_copy.items():
    plt.plot(saved_history['loss'][start_epoch:], label=name+' training loss', alpha=.8)
    plt.plot(saved_history['val_loss'][start_epoch:], label=name+' validation loss', alpha=.8)
plt.title('Loss')
plt.legend()
plt.grid(alpha=.3)

# Plot training and validation accuracy
plt.figure(figsize=(15, 6))
for name, (_, _, saved_history) in metadata_copy.items():
    plt.plot(saved_history['accuracy'][start_epoch:], label=name+' training accuracy', alpha=.8)
    plt.plot(saved_history['val_accuracy'][start_epoch:], label=name+' validation accuracy', alpha=.8)
plt.title('Accuracy')
plt.legend()
plt.grid(alpha=.3)

plt.show()
# Out:
# convnextlarge_baseaug_3randaug0.5_3augmix0.3_flatten train accuracy: 64.55
# convnextlarge_baseaug_3randaug0.5_3augmix0.3_flatten validation accuracy: 93.39
# FT_convnextlarge_baseaug_3randaug0.5_3augmix0.3_flatten_freeze0 train accuracy: 91.66
# FT_convnextlarge_baseaug_3randaug0.5_3augmix0.3_flatten_freeze0 validation accuracy: 96.91

# %% [markdown]
# ## Confusion Matrixes
# Here we perform a strong augmentation on the validation set to see if our model is able to make predictions on distorted images.
# This was useful because the accuracy on the augmented validation set was closer to the Codabench test set.
# Below we print the accuracy and confusion matrixes of, respectively, both the validation set (without augmentation) and validation set with augmentation

# %%
test_augmentation_layer = tf.keras.Sequential([
    tfkl.RandomFlip("horizontal_and_vertical"),
    tfkl.RandomTranslation(0.4,0.4),
    tfkl.RandomRotation(0.4),
    tfkl.RandomZoom(0.4),
    tfkl.RandomBrightness(0.7, value_range=(0,255)),
    tfkl.RandomContrast(0.85),
    tfkl.GaussianNoise(0.15)
], name='augmentation')

X_val_augmented = test_augmentation_layer(X_val)

# %%
# Load the saved model
saved_model = tfk.models.load_model(ft_model_filename)

# %%
for X_val_i in [X_val, X_val_augmented]:
    # Predict labels for the entire test set
    predictions = saved_model.predict(X_val_i, verbose=0)

    # Display the shape of the predictions
    print("Predictions Shape:", predictions.shape)

    # Convert predictions to class labels
    pred_classes = np.argmax(predictions, axis=-1)

    # Extract ground truth classes
    true_classes = np.argmax(y_val, axis=-1)

    # Calculate and display val set accuracy
    accuracy = accuracy_score(true_classes, pred_classes)
    print(f'Accuracy score over the val set: {round(accuracy, 4)}')

    # Calculate and display val set precision
    precision = precision_score(true_classes, pred_classes, average='weighted')
    print(f'Precision score over the val set: {round(precision, 4)}')

    # Calculate and display val set recall
    recall = recall_score(true_classes, pred_classes, average='weighted')
    print(f'Recall score over the val set: {round(recall, 4)}')

    # Calculate and display val set F1 score
    f1 = f1_score(true_classes, pred_classes, average='weighted')
    print(f'F1 score over the val set: {round(f1, 4)}')

    # Compute the confusion matrix
    cm = confusion_matrix(true_classes, pred_classes)

    # Combine numbers and percentages into a single string for annotation
    annot = np.array([f"{num}" for num in cm.flatten()]).reshape(cm.shape)

    # Plot the confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm.T, annot=annot, fmt='', xticklabels=list(labels.values()), yticklabels=list(labels.values()), cmap='Blues')
    plt.xlabel('Predicted labels')
    plt.ylabel('True labels')
    plt.show()
# Out:
# Predictions Shape: (1196, 8)
# Accuracy score over the val set: 0.9691
# Precision score over the val set: 0.9702
# Recall score over the val set: 0.9691
# F1 score over the val set: 0.9691
# Predictions Shape: (1196, 8)
# Accuracy score over the val set: 0.8161
# Precision score over the val set: 0.8247
# Recall score over the val set: 0.8161
# F1 score over the val set: 0.8175
